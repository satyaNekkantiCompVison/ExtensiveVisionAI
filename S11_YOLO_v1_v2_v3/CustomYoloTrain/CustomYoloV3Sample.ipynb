# %%
# !git clone https://github.com/theschoolofai/YoloV3.git
# Out:
# Cloning into 'YoloV3'...
# remote: Enumerating objects: 139, done.
# remote: Counting objects: 100% (139/139), done.
# remote: Compressing objects: 100% (131/131), done.
# remote: Total 139 (delta 1), reused 139 (delta 1), pack-reused 0
# Receiving objects: 100% (139/139), 10.46 MiB | 16.33 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.10.0+cu111 _CudaDeviceProperties(name='Tesla K80', major=3, minor=7, total_memory=11441MB, multi_processor_count=13)

# %%
ls
# Out:
# '00828599 (1).pdf'
# '00828599 (2).pdf'
#  00828599.pdf
#  131398016_1616750359448.pdf
#  131398016_1635230281198.pdf
#  201807030842378600EY92030720.pdf
#  2021-02-07-15-19-08-390_1612691348390_XXXPN9827X_ITRV.pdf
#  2208/
#  Aadharbackside.jpeg
#  Aadharfrontside.jpeg
# 'Algorithm Collections for Digital Signal Processing Applications using Matlab - E.S. Gopi.pdf'
# 'Algorithm Collections for Digital Signal Processing Applications using Matlab - E.S. Gopi.rar'
#  Bankstattements.pdf
# 'Case Study – Balance between Equity and Bond Investments.gdoc'
#  Chit_Returns.gsheet
# 'Colab Notebooks'/
# 'Content Documentation.gdoc'
# 'Content Sheet.gsheet'
# 'Copy of decision_tree_regression.ipynb'
# 'Copy of multiple_linear_regression.ipynb'
# 'Copy of polynomial_regression.ipynb'
# 'Copy of random_forest_regression.ipynb'
# 'Copy of support_vector_regression.ipynb'
#  CustomYolo/
#  dbs-fund-information.pdf
# ...

# %%
# %cd /content/gdrive/MyDrive/CustomYolo/
# !ls
# Out:
# /content/gdrive/MyDrive/CustomYolo
#  annotation_tool   detect.py   __pycache__   test.py	      utils
#  cfg		   models.py   runs	     train.py	      vim.exe.stackdump
#  data		   output      test_output  'ubdivisions=1'   weights

# %%
# !python train.py --data data/smalcoco/smalcoco.data --batch 3 --cache --epochs 3 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=3, bucket='', cache_images=True, cfg='cfg/yolov3-spp.cfg', data='data/smalcoco/smalcoco.data', device='', epochs=3, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-04-17 15:50:27.389103: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.29987e+07 parameters, 6.29987e+07 gradients
# Caching labels (20 found, 0 missing, 0 empty, 0 duplicate, for 20 images): 100% 20/20 [00:00<00:00, 6747.05it/s]
# Caching images (0.0GB): 100% 20/20 [00:00<00:00, 129.73it/s]
# ...

# %%
# !python train.py --data data/customData/custom.data --batch 16 --cache --cfg cfg/yolov3-custom.cfg --epochs 1 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=16, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customData/custom.data', device='', epochs=1, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla K80', total_memory=11441MB)
#
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# Caching labels (89 found, 1 missing, 0 empty, 0 duplicate, for 90 images): 100% 90/90 [00:15<00:00,  5.73it/s]
# Caching images (0.1GB): 100% 90/90 [00:16<00:00,  5.37it/s]
# Reading image shapes: 100% 10/10 [00:02<00:00,  4.96it/s]
# ...

# %%
# !python train.py --data data/customData/custom.data --batch 16 --cache --cfg cfg/yolov3-custom.cfg --epochs 50 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=16, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customData/custom.data', device='', epochs=50, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla K80', total_memory=11441MB)
#
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# Caching labels (89 found, 1 missing, 0 empty, 0 duplicate, for 90 images): 100% 90/90 [00:00<00:00, 624.37it/s]
# Caching images (0.1GB): 100% 90/90 [00:00<00:00, 171.23it/s]
# ...

# %%
# !python detect.py --conf-thres 0.1 --source inp_video_frames --output video_frames
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='video_frames', save_txt=False, source='inp_video_frames', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla K80', total_memory=11441MB)
#
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# image 1/102 inp_video_frames/001.jpg: 512x320 2 hardhats, 1 vests, 2 masks, Done. (0.110s)
# image 2/102 inp_video_frames/002.jpg: 512x320 2 hardhats, 1 vests, 3 masks, 1 bootss, Done. (0.111s)
# ...

# %%
Image(filename='inp_video_frames/095.jpg', width=100)
